# %%
l=(['', '[UNK]', 'है।', 'हैं।', 'चाहिए।', 'था।', 'होगा।', 'चुटिये', 'मुझ्े', 'हूं।', 'जाएगा।', 'करें।', '😂😂', 'दिया।', 'किया।', 'हो।', 'चुटियापा', 'नहीं।', 'डाला।', '😂😂😂', 'एच।', 'लिए।', 'ब्क', 'थी।', 'रनुं', '😂😂😂😂', 'मदर्छोड़', 'गया।', 'लल्लांटॉप', 'बोरादे', 'भ्ट', 'भाई।', 'दें।', 'एकडम', 'म्तल्ब', '😊', 'होगी।', 'थे।', 'की।', 'होंगे।', 'भोस्डिके', '👍', 'जाये।', 'जाएगी।', 'करो।', 'बेकचोड़ी', 'नही।', 'ठप्पड', 'छूट्या', 'गए।', 'को।', 'अछए', '🤣🤣🤣🤣', '🤣🤣', '🤣', '\u200b\u200bकि', 'हहाहा', 'से।', 'वेदियो', 'म्स्ट', 'काम।', 'होता।', 'हू।', 'हूँ।', 'लॉन्दे', 'लाइब्राल्स', 'रखेगा।', 'भोसई', 'फामिनिस्ट', 'कहा।', 'ल्डकी', 'लिया।', 'लावड़े', 'मुझे।', 'ब्सक', 'दी।', 'करेगा।', '0347', '🤣🤣🤣', '🤔', '👌', 'स्वेताभ', 'स्म्झ', 'वह।', 'लो।', 'रहेंगे।', 'रखें।', 'म्जा', 'में।', 'मारा।', 'बख्वास', 'देगा।', 'देखा।', 'जाएंगे।', 'ग्ल्ट', 'क्रनी', 'कर।', 'एस्ली', 'एचएपीएस', 'आया।', 'haps', '😒', '😃', '😂😂😂😂😂', '😁', 'लगे।', 'र्हेंगे', 'रामाधिर', 'यार।', 'मिला।', 'भेंछोड', 'बोहॉट', 'फिल्म।', 'दो।', 'देखें।', 'देंगे।', 'तिक्टोक', 'झंत', 'जहील', 'जरूर्ट', 'ग्ल्टी', 'क्रोगे', 'के।', 'करेगी।', 'एनीम', 'єѕєѕєѕєѕ', 'arndhati', '😡😡😡', '😡', '😑😑', '😎', '😂🤣😂🤣', '️', 'होते।', 'हप्सवॉयुतुबेकॉमवाचवज़्ज़्सऔदकीक1मत3म47स', 'सुनो।', 'साथ।', 'व्ड़ो', 'वो।', 'लोदु', 'लाव्ड', 'रहेगा।', 'मैं।', 'मार्डो', 'ब्फ', 'ब्नटे', 'बोल्के', 'बेकचोड़', 'बेंचोड', 'फ्लीम', 'फेमिनिस्तों', 'पूछा।', 'पार्तिक', 'पाएंगे।', 'तू।', 'जे।', 'जायेगा।', 'ग्लोरिटी', 'ग्फ', 'गन्दुओ', 'गई।', 'ख्रब', 'कोई।', '🤣😂🤣😂', '🙏🙏', '🙄', '🙂', '😘', '😑', '😅', '😂🤣', '😂😂😂😂😂😂😂😂', '💝', '👍👍', '👌👌', 'हा।', 'हप्सय्तुबेएंदब772उआसू', 'स्म्झा', 'सकते।', 'व्हेत्सप्प', 'विदियो', 'ल्डकिया', 'लेड्के', 'लें।', 'लार्का', 'लाउलिट', 'लाइब्रांडु', 'म्क्ब', 'मारवाने', 'मारवाओ', 'माँ।', 'भोसडाइक', 'बात।', 'बरोथेर', 'बनाओ।', 'बत्व', 'फिर।', 'पड़ा।', 'न्ही।', 'देगी।', 'देखूंगा।', 'देखी।', 'दारजे', 'थीं।', 'डी।', 'डब्ल्यू।', 'ठांकु', 'टिकटोक', 'जी।', 'जाओ।', 'जाए।', 'ग्ण्डी', 'क्रूँगा', 'कुम्फू', 'कुँकी', 'का।', 'करेंगे।', 'करूंगा।', 'ओवरेक्टिंग', 'एचएएसपीएस', 'एक।', 'आपने।', 'अप्से', 'अनिम', 'अग्ग्रेसिव', 'єѕєѕ', 'єѕ', 'storikfp', 'sfnsn', 'searchquire', 'mkfesbukcom', 'fnlid', '🤭', '🙏🙏🙏🙏', '😡😡😡😡', '😠', '😒।', '😊👍👌', '😆😆😆', '😆😆', '😄😄', '😄', '😂😂🤣🤣', '😂😂👍', '😂😂।', '😁😁😁', '😀😀😀', '👹😠👊', '👌👌👌', '👇👇👇👇👇', 'होती।', 'हैं😂😂😂', 'हे।', 'हेन।', 'हुई।', 'हुआ।', 'हिज्रास', 'हिंद।', 'हाय।', 'हप्सवॉयुतुबेकॉमवाचवज2ज5स्प5य्कत11म14स', 'हत्या।', 'स्माझते', 'सैतन', 'सेक्सिम', 'सुध्रेगा', 'सुतसूर्यपुत्र', 'सिंह।', 'समीक्षा।', 'सकें।', 'सकता।', 'वैम्पंथियो', 'वैई', 'वेवो', 'विचर्धारा', 'वाह।', 'लोलोल', 'लॉडे', 'लैकियो', 'ली।', 'ललंटॉप', 'लड़का।', 'र्खना', 'र्क्स100', 'रॉय।', 'रीशीता', 'रानुन', 'राजदिप', 'रणना', 'रखना।', 'रंधी', 'रंगाबिल्ला', 'य्हा', 'मोदीशाह', 'मोंदोल', 'मॉडिस्ट', 'मैड्रे', 'मेन्सूत्र', 'मूलनिवसियों', 'मारवानी', 'मधरछोड़', 'भोसदिवालों', 'ब्रहमनो', 'ब्ड़िया', 'बोल्क', 'बोलो।', 'बेहच्छोड', 'बिचड़', 'बनाया।', 'फ्र्क', 'फ्रींग', 'फगड़ने', 'पुबग', 'पासंड', 'पाखंड।', 'पाएगा।', 'नीमजे', 'धन्यवाड', 'धनार', 'दोस्त।', 'देश।', 'देखो।', 'दिखाएंगे।', 'थनोस', 'त्य्म', 'तु।', 'डेडो', 'ट्रिंगा', 'झातु', 'जिंदेगी', 'जाएं।', 'जहिल', 'छुट्ये', 'च्जे', 'चॉटी', 'चाणक्यचंद्रगुप्त', 'घट्या', 'गैंडु', 'गांडवो', 'गल्ट', 'क्रोगी', 'क्रार', 'कोशाल', 'कुथी', 'कुत्तोन', 'कीजिये।', 'कहेंगे।', 'कर्दी', 'कर्दिया', 'करे।', 'करके।', 'कनूँ', 'कदवी', 'कत्तम', 'औलिटेरा', 'और।', 'एक्सप्लैनेशन', 'ई।', 'इससे।', 'आतनवाड़ी', 'आतंकवाड़ी', 'आई।', 'अरुंधुती', 'अपने।', 'अटंकबड़ी', 'अज्ञांता', 'अंध्भक्त', 'αєѕα', 'wawy।', 'storifbid', 'skwspwa', 'jipd', 'jhb', '504756703591356', '200300', '100200', '100021710923207', '🤣🤣🤣🤣🤣🤣🤣🤣', '🤣😂😂😂', '🤣😂', '🤘🤘🤘🤘', '🙃', '😩😩😩', '😢😢😢😢😢😢', '😡😡😡😡😡😡', '😡😡😡😡😡', '😘😘😘😘', '😔', '😏😏', '😏', '😎😎😎', '😊😊', '😊👍', '😉', '😈😈', '😇', '😆😆😅🤣🤣', '😂😂😜😜', '😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂', '😂😂😂😂।', '😂😂😂।', '😂👌', '😁😁😂😂😝😝', '😁😁', '😀😂', '🔥', '👿👿👿', '👍👍👍', '👍👌', '👌👌👌👌', '👌🏻🔥', '🎭', '🇮🇳🙏🇮🇳🙏🇮🇳🙏🇮🇳🙏', '✌️✌️', '⚪', '☺☺👌', '\u200b\u200bमहिलाओं', 'ह😂😂', 'होराई', 'होबुत', 'होग।', 'होगे।', 'होक्र', 'हैं😂', 'हैंलड़की', 'हिल्लाना', 'हिप्पॉक्रिसी', 'हिन्द।', 'हिज्दो', 'हिज़्दो', 'हिज़्ड़े', 'हिंदूमुस्लिम', 'हिंडेतन', 'हरमझदी', 'हरमजादी', 'हयाना', 'हप्सवॉयुतुबेकॉमवाचवनज़्मक़मजोस0त17म26स', 'हप्सवॉयुतुबेकॉमवाचवनज़्मक़मजोस0त17म25स', 'हप्सवॉयुतुबेकॉमवाचवनज़्मक़मजोस0त13म08स', 'हप्सवॉयुतुबेकॉमवाचवज़्ज़्सऔदकीक1मत3म50स', 'हप्सवॉयुतुबेकॉमवाचवज़्ज़्सऔदकीक1मत2म14स', 'हप्सय्तुबेनेक्क07क़्त2ग', 'स्वेताब', 'स्वातब', 'स्म्झते', 'स्मार्टिस', 'स्पोइलर', 'स्टेटम', 'स्ज़ा', 'सौदीडो', 'सोनमैन', 'सुस्त।', 'सुबरिबर', 'सुगरता', 'सिनदी', 'सिद्धांत।', 'सिग्नीफिका', 'सिखाओ।', 'सिखाएं।', 'साले।', 'साला।', 'सायाद', 'सामजीक', 'सानिमा', 'सही।', 'सहमति।', 'सर्काइले', 'सरपिरी', 'सरदेई', 'समझेंगे।', 'समझता।', 'सब।', 'सच।', 'सकती।', 'श्वेतेभ', 'श्वेतेंक', 'श्वेताब', 'व्यक्ति।', 'व्गेरा', 'वूओ', 'वुस्को', 'वुमनिजर', 'वीडियो।', 'वालों।', 'वागवान', 'वांडे', 'वहाप', 'वजैसे', 'वऑ', 'लोस्ट्री', 'लोग।', 'लोकगो', 'लॉग।', 'लेडको', 'लेडकी', 'लेखेन', 'लिखूंगा।', 'लाव्फ', 'लाउंडी', 'लाइब्रान्डो', 'लल्लानाटॉप', 'लड़की।', 'लग्रह', 'लगी।', 'लगबक़', 'र्हना', 'र्खो', 'रैंडत', 'रेवीवे', 'रूगिस', 'रीवियूज', 'रामामंडल', 'रामवंडे', 'राममांडल', 'राजीप', 'राजबोंगशी', 'रहे।', 'रविह', 'रऑन्दिस', 'युतुबर', 'यह।', 'म्री', 'म्न्दी', 'म्गतो', 'म्को', 'मोबर्क', 'मोनुं', 'मॉर्डो', 'मे😂😂😂😂😂😂', 'मेडरछोड', 'मेटालैब', 'मूवी।', 'मूवई', 'मुरुगनमथम', 'मुद्दे।', 'मुज्रिम', 'मि।', 'मिसउसे', 'मिलेगी।', 'मार्डंगी', 'मार्टो', 'माराã', 'मादरछोड़', 'मातरमो', 'महातर', 'मदिस', 'मदारोंओध', 'मदारचोत', 'मदरचुदा', 'मदरची', 'भ्सक', 'भोसदी', 'भोसदिवाली', 'भोजदी', 'भैजान', 'भारत।', 'भद्वे', 'ब्राह्मानों', 'ब्रबाड', 'ब्न्या', 'ब्न्ती', 'ब्नता', 'ब्कोज़', 'बोस्डाइक', 'बोसादिक', 'बोसदिके', 'बोल्डो'])

# %%
print(l
      )
# Out:
# ['', '[UNK]', 'है।', 'हैं।', 'चाहिए।', 'था।', 'होगा।', 'चुटिये', 'मुझ्े', 'हूं।', 'जाएगा।', 'करें।', '😂😂', 'दिया।', 'किया।', 'हो।', 'चुटियापा', 'नहीं।', 'डाला।', '😂😂😂', 'एच।', 'लिए।', 'ब्क', 'थी।', 'रनुं', '😂😂😂😂', 'मदर्छोड़', 'गया।', 'लल्लांटॉप', 'बोरादे', 'भ्ट', 'भाई।', 'दें।', 'एकडम', 'म्तल्ब', '😊', 'होगी।', 'थे।', 'की।', 'होंगे।', 'भोस्डिके', '👍', 'जाये।', 'जाएगी।', 'करो।', 'बेकचोड़ी', 'नही।', 'ठप्पड', 'छूट्या', 'गए।', 'को।', 'अछए', '🤣🤣🤣🤣', '🤣🤣', '🤣', '\u200b\u200bकि', 'हहाहा', 'से।', 'वेदियो', 'म्स्ट', 'काम।', 'होता।', 'हू।', 'हूँ।', 'लॉन्दे', 'लाइब्राल्स', 'रखेगा।', 'भोसई', 'फामिनिस्ट', 'कहा।', 'ल्डकी', 'लिया।', 'लावड़े', 'मुझे।', 'ब्सक', 'दी।', 'करेगा।', '0347', '🤣🤣🤣', '🤔', '👌', 'स्वेताभ', 'स्म्झ', 'वह।', 'लो।', 'रहेंगे।', 'रखें।', 'म्जा', 'में।', 'मारा।', 'बख्वास', 'देगा।', 'देखा।', 'जाएंगे।', 'ग्ल्ट', 'क्रनी', 'कर।', 'एस्ली', 'एचएपीएस', 'आया।', 'haps', '😒', '😃', '😂😂😂😂😂', '😁', 'लगे।', 'र्हेंगे', 'रामाधिर', 'यार।', 'मिला।', 'भेंछोड', 'बोहॉट', 'फिल्म।', 'दो।', 'देखें।', 'देंगे।'
# ...

# %%
l=" ".join(l)
print(l)
# Out:
#  [UNK] है। हैं। चाहिए। था। होगा। चुटिये मुझ्े हूं। जाएगा। करें। 😂😂 दिया। किया। हो। चुटियापा नहीं। डाला। 😂😂😂 एच। लिए। ब्क थी। रनुं 😂😂😂😂 मदर्छोड़ गया। लल्लांटॉप बोरादे भ्ट भाई। दें। एकडम म्तल्ब 😊 होगी। थे। की। होंगे। भोस्डिके 👍 जाये। जाएगी। करो। बेकचोड़ी नही। ठप्पड छूट्या गए। को। अछए 🤣🤣🤣🤣 🤣🤣 🤣 ​​कि हहाहा से। वेदियो म्स्ट काम। होता। हू। हूँ। लॉन्दे लाइब्राल्स रखेगा। भोसई फामिनिस्ट कहा। ल्डकी लिया। लावड़े मुझे। ब्सक दी। करेगा। 0347 🤣🤣🤣 🤔 👌 स्वेताभ स्म्झ वह। लो। रहेंगे। रखें। म्जा में। मारा। बख्वास देगा। देखा। जाएंगे। ग्ल्ट क्रनी कर। एस्ली एचएपीएस आया। haps 😒 😃 😂😂😂😂😂 😁 लगे। र्हेंगे रामाधिर यार। मिला। भेंछोड बोहॉट फिल्म। दो। देखें। देंगे। तिक्टोक झंत जहील जरूर्ट ग्ल्टी क्रोगे के। करेगी। एनीम єѕєѕєѕєѕ arndhati 😡😡😡 😡 😑😑 😎 😂🤣😂🤣 ️ होते। हप्सवॉयुतुबेकॉमवाचवज़्ज़्सऔदकीक1मत3म47स सुनो। साथ। व्ड़ो वो। लोदु लाव्ड रहेगा। मैं। मार्डो ब्फ ब्नटे बोल्के बेकचोड़ बेंचोड फ्लीम फेमिनिस्तों पूछा। पार्तिक पाएंगे। तू। जे। जायेगा। ग्लोरिटी ग्फ गन्दुओ गई। ख्रब कोई। 🤣😂🤣😂 🙏🙏 🙄 🙂 😘 😑 😅 😂🤣 😂😂😂😂😂😂😂😂 💝 👍👍 👌👌 हा। हप्सय्
# ...

# %%
import re

# %%
def cleanData(l):
  text = re.sub("[^\u0900-\u097F]+"," ",l)
  text = re.sub("[।]"," ",text)
  return text

# %%
print(type(text))
# Out:
# <class 'str'>

# %%
print(text)
# Out:
#  है  हैं  चाहिए  था  होगा  चुटिये मुझ्े हूं  जाएगा  करें  दिया  किया  हो  चुटियापा नहीं  डाला  एच  लिए  ब्क थी  रनुं मदर्छोड़ गया  लल्लांटॉप बोरादे भ्ट भाई  दें  एकडम म्तल्ब होगी  थे  की  होंगे  भोस्डिके जाये  जाएगी  करो  बेकचोड़ी नही  ठप्पड छूट्या गए  को  अछए कि हहाहा से  वेदियो म्स्ट काम  होता  हू  हूँ  लॉन्दे लाइब्राल्स रखेगा  भोसई फामिनिस्ट कहा  ल्डकी लिया  लावड़े मुझे  ब्सक दी  करेगा  स्वेताभ स्म्झ वह  लो  रहेंगे  रखें  म्जा में  मारा  बख्वास देगा  देखा  जाएंगे  ग्ल्ट क्रनी कर  एस्ली एचएपीएस आया  लगे  र्हेंगे रामाधिर यार  मिला  भेंछोड बोहॉट फिल्म  दो  देखें  देंगे  तिक्टोक झंत जहील जरूर्ट ग्ल्टी क्रोगे के  करेगी  एनीम होते  हप्सवॉयुतुबेकॉमवाचवज़्ज़्सऔदकीक मत म स सुनो  साथ  व्ड़ो वो  लोदु लाव्ड रहेगा  मैं  मार्डो ब्फ ब्नटे बोल्के बेकचोड़ बेंचोड फ्लीम फेमिनिस्तों पूछा  पार्तिक पाएंगे  तू  जे  जायेगा  ग्लोरिटी ग्फ गन्दुओ गई  ख्रब कोई  हा  हप्सय्तुबेएंदब उआसू स्म्झा सकते  व्हेत्सप्प विदियो ल्डकिया लेड्के लें  लार्का लाउलिट लाइब्रांडु म्क्ब मारवाने मारवाओ माँ  भोसडाइक बात  बरोथेर बना
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd

# %%
df1=pd.read_excel("/content/FinalHinTrainTrac2_BackTran.xlsx")

# %%
df1.head()
# Out:
#    Unnamed: 0         ID  ... Sub-task A Sub-task B
# 0           0     C4.131  ...        NAG       NGEN
# 1           1     C4.638  ...        NAG       NGEN
# 2           2    C38.598  ...        OAG       NGEN
# 3           3  C4.2101.1  ...        OAG       NGEN
# 4           4   C29.14.2  ...        NAG       NGEN
#
# [5 rows x 5 columns]

# %%
df2=pd.read_excel("/content/FinalHinDevTrac2_BackTran.xlsx")

# %%
df2.head()
# Out:
#    Unnamed: 0       ID  ... Sub-task A Sub-task B
# 0           0    C38.9  ...        OAG       NGEN
# 1           1  C4.1510  ...        NAG       NGEN
# 2           2   C19.95  ...        NAG       NGEN
# 3           3   C4.281  ...        OAG       NGEN
# 4           4   C4.216  ...        NAG       NGEN
#
# [5 rows x 5 columns]

# %%
(df1['data'][0])
# Out:
# 'बॉलीवुड फिल्म देखने के समय तर्क घर में चोरके एना पार्ता हैं। कृपया तर्क चटाई घुसओ'

# %%
s=cleanData(df1['data'][0])
print(s)
df1['data'][0].replace(df1['data'][0],s)
print(df1['data'][0])
# Out:
# बॉलीवुड फिल्म देखने के समय तर्क घर में चोरके एना पार्ता हैं  कृपया तर्क चटाई घुसओ
# बॉलीवुड फिल्म देखने के समय तर्क घर में चोरके एना पार्ता हैं। कृपया तर्क चटाई घुसओ

# %%
import xlwt
from xlwt import Workbook
  
# Workbook is created
wb = Workbook()
  
# add_sheet is used to create sheet.
sheet1 = wb.add_sheet('Sheet 1')

# %%
sheet1.write(1,1,s)

# %%
wb.save('xlwt example.xls')
